# %%
import gmaps
import pandas as pd

gmaps.configure(api_key='AIzaSyAKaR9jZime8X2HQfLvdWy1Lg6Dm0V93ZE')
fig = gmaps.figure(zoom_level = 13,center=(40.75,-74.00))

def usedata(x):
    directory = str(x) + '.csv'
    df = pd.read_csv(directory,names=['longitude','latitude','count'])
    df = df[(df.latitude < 90)]
    return df

# %%
df = usedata(11.0)

# %%
df
# Out:
#        longitude  latitude  count
# 0        -73.713    40.661      2
# 1        -73.737    40.681      2
# 2        -73.740    40.678      2
# 3        -73.755    40.719      4
# 4        -73.758    40.680      6
# 5        -73.760    40.669      2
# 6        -73.764    40.706      2
# 7        -73.767    40.666      2
# 8        -73.768    40.724      2
# 9        -73.772    40.679      2
# 10       -73.773    40.674      4
# 11       -73.774    40.651      4
# 12       -73.775    40.647      6
# 13       -73.775    40.665      4
# 14       -73.776    40.653      2
# 15       -73.776    40.671      2
# 16       -73.777    40.649      2
# 17       -73.777    40.650      2
# 18       -73.777    40.667      4
# 19       -73.777    40.748      2
# 20       -73.778    40.743      6
# 21       -73.779    40.658      4
# 22       -73.780    40.696      2
# 23       -73.780    40.722      2
# 24       -73.781    40.648     38
# 25       -73.781    40.666      4
# ...

# %%
heatmap_layer = gmaps.heatmap_layer(df[['latitude', 'longitude']], weights=df['count'], max_intensity=100, point_radius=3
)
heatmap_layer.opacity = 0.7
#heatmap_layer.gradient = ['green','yellow','red']
fig.add_layer(heatmap_layer)
fig
#press the top right button to get HD fullscreen view
# Out:
# A Jupyter Widget
